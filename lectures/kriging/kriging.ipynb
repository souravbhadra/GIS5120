# %%
import numpy as np
import pandas as pd
import gstools as gs
import matplotlib.pyplot as plt

# %%
points = pd.read_csv('points.csv', index_col=0)

# %%
points.head()
# Out:
#      x   y    z
# 0   23  35  940
# 1   95   5  890
# 2   96  43  915
# 3  162  17  870
# 4  146  47  880

# %%
plt.scatter(
    points['x'],
    points['y']
)
plt.show()

# %%
plt.scatter(
    points['x'],
    points['y'],
    c=points['z'],
    cmap='rainbow'
)
plt.colorbar()
plt.show()

# %%
# Extracting coordinates and z values
x = points['x'].values
y = points['y'].values
z = points['z'].values

# %%
model = gs.Exponential(dim=2, var=2, len_scale=8)
srf = gs.SRF(model, mean=0, seed=19970221)
field = srf((x, y))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Calculate empirical variogram
# ----> 2 bin_center, gamma = gs.vario.estimator((x, y), z, binning="even", n_lags=15)
#       4 # Print the empirical variogram values
#       5 print(bin_center, gamma)
#
# AttributeError: module 'gstools' has no attribute 'vario'

# %%
https://learn.arcgis.com/en/projects/interpolate-temperatures-using-the-geostatistical-wizard/
